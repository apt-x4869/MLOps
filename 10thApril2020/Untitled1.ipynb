# %%
import cv2

# %%
# to connect webcam 0-->default 1-->another webcam ....
cap = cv2.VideoCapture(0)

# %%
status, photo = cap.read()

# %%
photo
# Out:
# array([[[ 17,  63,   7],
#         [ 15,  61,   6],
#         [ 12,  57,   4],
#         ...,
#         [  0,   4,   0],
#         [  0,   4,   0],
#         [  0,   4,   0]],
#
#        [[ 15,  61,   6],
#         [ 18,  64,   8],
#         [ 14,  60,   5],
#         ...,
#         [  0,   4,   0],
#         [  0,   4,   0],
#         [  0,   4,   0]],
#
#        [[ 15,  61,   6],
#         [ 15,  61,   6],
#         [ 20,  63,   8],
#         ...,
#         [  0,   4,   0],
#         [  0,   4,   0],
#         [  0,   4,   0]],
#
#        ...,
#
#        [[163, 163, 156],
#         [164, 164, 157],
#         [164, 164, 157],
#         ...,
#         [ 33,  36,  26],
#         [ 27,  30,  20],
#         [ 30,  34,  24]],
#
#        [[163, 163, 156],
#         [163, 163, 156],
#         [164, 164, 157],
#         ...,
#         [ 33,  36,  26],
#         [ 33,  35,  28],
#         [ 28,  30,  23]],
#
#        [[163, 163, 156],
#         [163, 163, 156],
#         [161, 162, 155],
#         ...,
#         [ 36,  39,  30],
#         [ 37,  40,  32],
#         [ 36,  39,  31]]], dtype=uint8)

# %%
cv2.imshow('hi',photo)
cv2.waitKey(5000)
cv2.destroyAllWindows()
