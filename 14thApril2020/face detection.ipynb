# %%
import cv2
import numpy as np

# %%
cap = cv2.VideoCapture(0)
count = []

# %%
face_model = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
while True:
    status, photo = cap.read()
    face = face_model.detectMultiScale(photo)
    if len(face)==0:
        pass
    else:
        for x in range(len(face)):
            x1 = face[x][0]
            y1 = face[x][1]
            x2 = x1 + face[x][2]
            y2 = y1 + face[x][3]          
            photo = cv2.rectangle(photo, (x1,y1), (x2,y2), [0,255,0], 3)
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    org = (10,50)
    fontScale = 2
    fontColor = (255,255,255)
    lineType = 2
    cv2.putText(photo, str(len(face)), org, font, fontScale, fontColor, 10, cv2.LINE_AA, False)
    count.append(len(face))
    cv2.imshow('hell', photo)
    if cv2.waitKey(10) == 13:
            break
cv2.destroyAllWindows()

# %%
cap.release()

# %%
# cv2.putText()
# take attandance as average , how many people are there and mail it to someone
# detect eyes
count = sum(count)/len(count)

# %%
count
# Out:
# 1.7777777777777777

# %%
print("hello \r\n hello2")
# Out:
# hello
#  hello2
