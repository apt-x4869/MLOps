# %%
from scipy import misc
from scipy.signal import convolve2d

# %%
img = misc.ascent()

# %%
img.shape
# Out:
# (512, 512)

# %%
kernel = np.array([[1,5,1],[100,0,5],[1,0,5]])

# %%
c = convolve2d(img,kernel)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(c, cmap='gray')

# %%
plt.plot(c)
